# %%
import pandas as pd
# Sample data
df=pd.read_csv(r"F:\Pandas dataset\Latest Covid-19 India Status.csv")

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
(df.head())
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
plt.figure(figsize=(50,50))
plt.bar(df['State/UTs'], df['Deaths'], color='red', label='Deaths')
plt.xlabel('State/UTs')
plt.ylabel('Deaths')
plt.title('State wise Deaths')
plt.xticks(rotation=50)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['State/UTs'], df['Deaths'], marker='o', color='b', label='Deaths')
plt.xlabel('State/UTs')
plt.ylabel('Deaths')
plt.title('State-wise Deaths')
plt.legend()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()       # Adjust layout to make room for x-axis labels
plt.show()

# %%
plt.figure(figsize=(50,50))
plt.bar(df['State/UTs'], df['Total Cases'], color='red', label='Deaths')
plt.xlabel('State/UTs')
plt.ylabel('Total Cases')
plt.title('State/UTs:Total Cases ')
plt.xticks(rotation=50)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['State/UTs'], df['Total Cases'], marker='o', color='b', label='Total Cases')
plt.xlabel('State/UTs')
plt.ylabel('Total Cases')
plt.title('Total Cases :State/UTs')
plt.legend()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()       # Adjust layout to make room for x-axis labels
plt.show()


#1e6 is standard scientific notion, and here it indicates an overall scale factor for the y-axis. 
#That is, if there's a 2 on the y-axis and a 1e6 at the top,
#the value at 2 actually indicates 2*1e6 = 2e6 = 2 * 10^6 = 2,000,000

# %% [raw]
# #IMPORTANT INFORMATION
#
# #Labels: Use plt.xlabel() and plt.ylabel() to add labels to the x and y axes.
# #Title: Use plt.title() to add a title to the chart.
# #Legend: Use plt.legend() to add a legend. The label parameter in the plt.bar() or plt.plot() functions defines the legend text.
# #Rotate X-axis Labels: Use plt.xticks(rotation=90) to rotate the x-axis labels for better readability.
# #Layout Adjustment: Use plt.tight_layout() to adjust the layout and make room for the x-axis labels
